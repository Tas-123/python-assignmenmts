# %%
#Question no.1
print ("Twinkle,twinkle,little,star \n \t how I wonder what you are! \n \t \t up above the world so high,\n \t \t  like a diamond in the sky.\n Twinkle,twinkle,little,star, \n \t How I Wonder what you are   ")
# Out:
# Twinkle,twinkle,little,star
#  	 how I wonder what you are!
#  	 	 up above the world so high,
#  	 	  like a diamond in the sky.
#  Twinkle,twinkle,little,star,
#  	 How I Wonder what you are

# %%
#Question no.2
import sys
print(sys.version)
# Out:
# 3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]

# %%
#Question no.3
import datetime
e=datetime.datetime.now()
print("current date and time = %s" %e)
print("today's date: = %s/%s/%s"%(e.day, e.month, e.year))
print("the time is now: = %s:%s:%s"%(e.hour, e.minute, e.second))
# Out:
# current date and time = 2021-12-30 12:49:45.059262
# today's date: = 30/12/2021
# the time is now: = 12:49:45

# %%
#Question no.4
from math import pi
r=float(input("enter value of radius of circle:"))
print("the area of circle with radius" +str(r) +"is" +str( pi*r**2))
# Out:
# enter value of radius of circle:4
# the area of circle with radius4.0is50.26548245743669

# %%
#Question no.5
firstname=input("INPUT YOUR FIRST NAME :")
lastname =input("INPUT YOUR LAST NAME  :")
print(lastname+""+firstname)
# Out:
# INPUT YOUR FIRST NAME :Taimur
# INPUT YOUR LAST NAME  :Ali sakhawat
# Ali sakhawatTaimur

# %%
#Question no.6
x=input("INPUT DEPENDENT CLAUSE:")
y=input ("INPUT INDEPENDENT CLAUSE:")
print(x + ","+y)
# Out:
# INPUT DEPENDENT CLAUSEBecause he got up early
# INPUT INDEPENDENT CLAUSEHe went for jogging
# Because he got up early,He went for jogging
